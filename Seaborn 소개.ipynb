# %%
import pandas as pd

# %%
df = pd.read_csv('KT_tput.csv')
df.head()
# Out:
#   comp          qrwt_cltm  qrwt_serv_rsrp  qrwt_serv_sinr  qrwt_app_rx_tput  \
# 0   KT  2018.1.2 14:05:33           -86.0            17.0         73501.126
# 1   KT  2018.1.2 14:05:34           -85.0            17.0        103846.846
# 2   KT  2018.1.2 14:05:35           -85.0            17.0        124639.520
# 3   KT  2018.1.2 14:05:36           -86.0            18.0        131780.608
# 4   KT  2018.1.2 14:05:37           -85.0            17.0         98740.224
#
#    qrwt_app_tx_tput     technology Unnamed: 7
# 0               0.0  LTE CA(20+10)        2CA
# 1               0.0  LTE CA(20+10)        2CA
# 2               0.0  LTE CA(20+10)        2CA
# 3               0.0  LTE CA(20+10)        2CA
# 4               0.0  LTE CA(20+10)        2CA

# %%
# %matplotlib inline 

df.plot(x='qrwt_cltm', y='qrwt_app_rx_tput')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
figure, ((ax1, ax2, ax3), (ax4, ax5, ax6)) = plt.subplots(nrows=2, ncols=3)
figure.set_size_inches(18, 8)

sns.pointplot(data=df[:100], x='qrwt_cltm', y='qrwt_app_rx_tput', ax=ax1)
sns.pointplot(data=df[:100], x='qrwt_cltm', y='qrwt_serv_sinr', ax=ax2)

# %%
figure.savefig('all.png')
